# %% [markdown]
# # Analysis for Continuous Improvement
#
# Author Name: Kameron Thomas
#
# 9-digit PID: 730514879
#
# Continuous Improvement embraces a belief there is _always room to make things better_. It is a mindset and process we value and practice in this course. In this assignment, you are able to practice continuous improvement and contribute to the design ideas of the course.
#
# ## Brainstorming Ideas
#
# Reflect on your personal experiences and observations in COMP110 and **brainstorm modifications to the course that _create value_ beyond its current design**. When brainstorming, try not to be critical of the ideas you come up with regarding scale, stakeholders impacted, or for any other reasons. In the markdown cell below, brainstorm 3 to 5 ideas you think would create value for you.
#
# Each brainstormed idea should state a. the suggested change or addition, b. what the expected value created, and c. which specific stakeholders would benefit.  If helpful, expand on the following template "The course should (state idea here) because it will (state value created here) for (insert stakeholders here)."
#
# Example A: "The course should use only examples from psychology experiments because it will be more relevant for students who are psychology majors."
#
# Example B: "The course should not have post-lesson questions because they are not useful for most students in the class."

# %% [markdown]
# ### Part 1. Creative Ideation
#
# 1. The course website should open links in a new tab instead of replacing the website page. THis has been one of few slight annoyances for the webiste which is overall far better than any other website the school owns/uses. THis change would help anyone who uses the website.
# 2. It would be a really cool addition to learn website building so that students in the class who want to perrsue this can just starting in comp 110 instead of a more specialized higher lever class.
# 3. There should be a coding challenge every year to see who can create a better connect carolina website. This could be a group project which would teach comp 110 students how to collaberate on a coding projects and could help the entire student population if a good website is actually made.
# 4. We should get rid of tests. In the real world there will be no timed tests were we have to know every piece of information we were ever taught, instead we will have the internat at our fingertips and will be expected to know how to use it to complete a job. THis will help every student taking th class.
# 5. I took an aerospace engineering class in highschool that had a really cool method of completing course material. At the beginning of the year, we were told we need x number of points in order to get a 100 in the class... this was the only talk of grades for the res tof the year. Instead, each assignment was worth a certain number of points. We had smaller assignments and larger assignments and also tests. We could choose to do a ton of smaller assignment instead of one larger assignment or maybe a few large assignment and some small ones and not worry about the tests. All assignments were completly optional and the goal was just to get the number of points we wanted. This took the pressure off of grades for the most part and allowed us to choose assignment that we were passionate about. I am unsure as to the viability of this method for this course but it could be a really interesting way of choosing assignments and making the class more interactive. It could also allow people to choose what sort of computer science work most interests them or would be most applicable to their future goals.

# %% [markdown]
# ## Connecting with Available Data
#
# The data you have available for this analysis is limited to the anonymized course survey you and your peers filled out a few weeks ago. The data is found in the `survey.csv` file in this exercise directory. Each row represents an individual survey response. Each column has a description which can be found on the project write-up here: <https://22s.comp110.com/exercises/ex08.html>
#
# Review the list of available data and identify which one of your ideas _does not_, or is _least likely to_, have relevant data to support the analysis of your idea to create value. In the box below, identify which of your ideas lacks data and suggest how we might be able to collect this data in the future. One aspect of _continuous improvement_ is trying to avoid "tunnel vision" where possible improvements are not considered because there is no data available to analyze it. Identifying new data sources can unlock improvements!

# %% [markdown]
# ### Part 2. Identifying Missing Data
#
# 1. Idea without sufficient data to analyze: My first idea
#
# 2. Suggestion for how to collect data to support this idea in the future: ask about course website critiques

# %% [markdown]
# ## Choosing an Idea to Analyze
#
# Consider those of your ideas which _do_ seem likely to have relevant data to analyze. If none of your ideas do, spend a few minutes and brainstorm another idea or two with the added connection of data available on hand and add those ideas to your brainstormed ideas list.
#
# Select the one idea which you believe is _most valuable_ to analyze relative to the others and has data to support the analysis of. In the markdown cell for Part 3 below, identify the idea you are exploring and articulate why you believe it is most valuable (e.g. widest impact, biggest opportunity for improvement, simplest change for significant improvement, and so on).

# %% [markdown]
# ### Part 3. Choosing Your Analysis
#
# 1. Idea to analyze with available data: My Fifth idea
#
# 2. This idea is more valuable than the others brainstormed because: It is more in depth, it could help every person taking th class, and it would be a profound change to the system of education that we know does not work for all.

# %% [markdown]
# ## Your Analysis
#
# Before you begin analysis, a reminder that we do not expect the data to support everyone's ideas and you can complete this exercise for full credit even if the data does not clearly support your suggestion or even completely refutes it. What we are looking for is a logical attempt to explore the data using the techniques you have learned up until now in a way that _either_ supports, refutes, or does not have a clear result and then to reflect on your findings after the analysis.
#
# Using the utility functions you created for the previous exercise, you will continue with your analysis in the following part. Before you begin, refer to the rubric on the technical expectations of this section in the exercise write-up.
#
# In this section, you are expected to interleave code and markdown cells such that for each step of your analysis you are starting with an English description of what you are planning to do next in a markdown cell, followed by a Python cell that performs that step of the analysis.

# %% [markdown]
# ### Part 4. Analysis
#
# We begin by changing some settings in the notebook to automatically reload changes to imported files.

# %%
# %reload_ext autoreload
# %autoreload 2

# %% [markdown]
# We continue by importing the helper functions from `data_utils`.

# %%
from data_utils import *
from tabulate import tabulate

# %% [markdown]
# Next, ... (you take it from here and add additional code and markdown cells to read in the CSV file and process it as needed)

# %%
SURVEY_DATA_CSV_FILE_PATH: str = "../../data/survey.csv"

# %% [markdown]
# This code allows me to read the survey in a coding sense so that i can make better use of it's data

# %%
data_rows: list[dict[str, str]] = read_csv_rows(SURVEY_DATA_CSV_FILE_PATH)

print(f"Data File Read: {SURVEY_DATA_CSV_FILE_PATH}")
print(f"{len(data_rows)} rows")
print(f"{len(data_rows[0].keys())} columns")
columns = data_rows[0].keys()
print(f"Columns names: {columns}")
# Out:
# Data File Read: ../../data/survey.csv
# 620 rows
# 35 columns
# Columns names: dict_keys(['row', 'year', 'unc_status', 'comp_major', 'primary_major', 'data_science', 'prereqs', 'prior_exp', 'ap_principles', 'ap_a', 'other_comp', 'prior_time', 'languages', 'hours_online_social', 'hours_online_work', 'lesson_time', 'sync_perf', 'all_sync', 'flipped_class', 'no_hybrid', 'own_notes', 'own_examples', 'oh_visits', 'ls_effective', 'lsqs_effective', 'programming_effective', 'qz_effective', 'oh_effective', 'tutoring_effective', 'pace', 'difficulty', 'understanding', 'interesting', 'valuable', 'would_recommend'])

# %% [markdown]
# I want to be bale to create very specific columns.

# %%
need: list[str] = column_values(data_rows, "tutoring_effective")

print(f"Column 'subject_age' has {len(need)} values.")
print("The first five values are:")

for i in range(5):
    if need[i] != "":
        print(need[i])
# Out:
# Column 'subject_age' has 620 values.
# The first five values are:
# 6
# 4
# 3

# %% [markdown]
# THis code will allow me to create more useable data types.

# %%
data_cols: dict[str, list[str]] = columnar(data_rows)

print(f"{len(data_cols.keys())} columns")
print(f"{len(data_cols['tutoring_effective'])} rows")
print(f"Columns names: {data_cols.keys()}")
# Out:
# 35 columns
# 620 rows
# Columns names: dict_keys(['row', 'year', 'unc_status', 'comp_major', 'primary_major', 'data_science', 'prereqs', 'prior_exp', 'ap_principles', 'ap_a', 'other_comp', 'prior_time', 'languages', 'hours_online_social', 'hours_online_work', 'lesson_time', 'sync_perf', 'all_sync', 'flipped_class', 'no_hybrid', 'own_notes', 'own_examples', 'oh_visits', 'ls_effective', 'lsqs_effective', 'programming_effective', 'qz_effective', 'oh_effective', 'tutoring_effective', 'pace', 'difficulty', 'understanding', 'interesting', 'valuable', 'would_recommend'])

# %% [markdown]
# Smaller data set creation template for future use.

# %%
data_cols_head: dict[str, list[str]] = head(data_cols, 5)

if len(data_cols_head.keys()) != len(data_cols.keys()) or len(data_cols_head["tutoring_effective"]) != 5:
    print("Complete your implementation of columnar in data_utils.py")
    print("Be sure to follow the guidelines above and save your work before re-evaluating!")

tabulate(data_cols_head, data_cols_head.keys(), "html")
# Out:
# '<table>\n<thead>\n<tr><th style="text-align: right;">  row</th><th style="text-align: right;">  year</th><th>unc_status                 </th><th>comp_major  </th><th>primary_major   </th><th>data_science  </th><th>prereqs                     </th><th>prior_exp                   </th><th>ap_principles  </th><th>ap_a  </th><th>other_comp                      </th><th>prior_time                  </th><th>languages               </th><th>hours_online_social  </th><th>hours_online_work  </th><th style="text-align: right;">  lesson_time</th><th style="text-align: right;">  sync_perf</th><th style="text-align: right;">  all_sync</th><th style="text-align: right;">  flipped_class</th><th style="text-align: right;">  no_hybrid</th><th style="text-align: right;">  own_notes</th><th style="text-align: right;">  own_examples</th><th style="text-align: right;">  oh_visits</th><th style="text-align: right;">  ls_effective</th><th style="text-align: right;">  lsqs_effective</th><th style="text-ali
# ...

# %% [markdown]
# This will allow me to look at a specific data set and pull x number of values from it.

# %%
selected_data: dict[str, list[str]] = select(data_cols, ['prior_time', 'hours_online_social', 'hours_online_work', 'lesson_time', 'sync_perf', 'all_sync', 'flipped_class', 'no_hybrid', 'own_notes', 'own_examples', 'oh_visits', 'ls_effective', 'lsqs_effective', 'programming_effective', 'qz_effective', 'oh_effective', 'tutoring_effective', 'pace', 'difficulty', 'understanding', 'interesting', 'valuable', 'would_recommend'])

tabulate(head(selected_data, 20), selected_data.keys(), "html")
# Out:
# '<table>\n<thead>\n<tr><th>prior_time                  </th><th>hours_online_social  </th><th>hours_online_work  </th><th style="text-align: right;">  lesson_time</th><th style="text-align: right;">  sync_perf</th><th style="text-align: right;">  all_sync</th><th style="text-align: right;">  flipped_class</th><th style="text-align: right;">  no_hybrid</th><th style="text-align: right;">  own_notes</th><th style="text-align: right;">  own_examples</th><th style="text-align: right;">  oh_visits</th><th style="text-align: right;">  ls_effective</th><th style="text-align: right;">  lsqs_effective</th><th style="text-align: right;">  programming_effective</th><th style="text-align: right;">  qz_effective</th><th>oh_effective  </th><th>tutoring_effective  </th><th style="text-align: right;">  pace</th><th style="text-align: right;">  difficulty</th><th style="text-align: right;">  understanding</th><th style="text-align: right;">  interesting</th><th style="text-align: right;">  valuable</
# ...

# %% [markdown]
# Count certain data types.

# %%
recommend: dict[str, int] = count(selected_data["would_recommend"])
print(f"Would recommend: {recommend}")

prior: dict[str, int] = count(selected_data["prior_time"])
print(f"Prior coding knowledge: {prior}")

hours: dict[str, int] = count(selected_data["hours_online_work"])
print(f"Hours spent doing classwork: {hours}")

own: dict[str, int] = count(selected_data["own_examples"])
print(f"How likely to make own examples: {own}")

interest: dict[str, int] = count(selected_data["interesting"])
print(f"Is this class interesting: {interest}")
# Out:
# Would recommend: {'5': 85, '4': 56, '7': 298, '6': 129, '3': 26, '2': 16, '1': 10}
# Prior coding knowledge: {'1 month or so': 69, '': 369, 'None to less than one month!': 102, '7-12 months': 14, '2-6 months': 49, '1-2 years': 10, '> 2 years': 7}
# Hours spent doing classwork: {'0 to 2 hours': 23, '5 to 10 hours': 270, '3 to 5 hours': 281, '10+ hours': 45, 'None': 1}
# How likely to make own examples: {'4': 123, '7': 103, '5': 161, '3': 77, '2': 32, '1': 14, '6': 110}
# Is this class interesting: {'5': 106, '4': 47, '7': 293, '6': 144, '1': 7, '3': 16, '2': 7}

# %%
examp: int = add(own)
print(f"This many people make up their own examples: {examp}")

pr: int = add(prior)
print(f"This many people have prior coding knowledge: {pr}")

n = 0
for i in recommend:
    n += recommend[i]

print(f"Total data points: {n}")
# Out:
# This many people make up their own examples: 374
# This many people have prior coding knowledge: 80
# Total data points: 620

# %%
from matplotlib import pyplot as plt

fig, axes = plt.subplots(1, 2, figsize=(12, 5), sharey=False)
fig.suptitle("Why my class style might work.")

items_in_dict: list[tuple[str, int]] = list(own.items())
items_in_dict = sorted(items_in_dict)

sort: dict[str, int] = dict(items_in_dict)

axes[0].set_title("Outside Experience")
axes[0].bar(prior.keys(), prior.values())
axes[0].tick_params(axis='x', labelrotation = 90)

axes[1].set_title("Makes Examples")
axes[1].bar(sort.keys(), sort.values())
axes[1].tick_params(axis='x', labelrotation = 90)

# %% [markdown]
# ## Conclusion
#
# In the following markdown cell, write a reflective conclusion given the analysis you performed and identify recommendations.
#
# If your analysis of the data supports your idea, state your recommendation for the change and summarize the data analysys results you found which support it. Additionally, describe any extensions or refinements to this idea which might be explored further. Finally, discuss the potential costs, trade-offs, or stakeholders who may be negatively impacted by this proposed change.
#
# If your analysis of the data is inconclusive, summarize why your data analysis results were inconclusive in the support of your idea. Additionally, describe what experimental idea implementation or additional data collection might help build more confidence in assessing your idea. Finally, discuss the potential costs, trade-offs, or stakeholders who may be negatively impacted by experimenting with your idea.
#
# Finally, if your analysis of the data does not support it, summarize your data analysis results and why it refutes your idea. Discuss the potential costs, trade-offs, or stakeholders who may be negatively impacted by this proposed change. If you disagree with the validity of the findings, describe why your idea still makes sense to implement and what alternative data would better support it. If you agree with the validity of the data analysis, describe what alternate ideas or extensions you would explore instead.

# %% [markdown]
# ### Part 5. Conclusion
#
#     My addition to the class would be to turn the class into a choose your own adventure sort of learning experience. To support this idea, I looked at the data in particular that showed how interested my peers are in the class. There is a section in the data specifically for this but I feel as though that mey be skewed for emotional purposes. Instead, I looked at data that would support this, such as how many people make their own examples up to code and how many people have prior coding experience. These statistics can help me gauge just how interested someone actually is. The prior coding knowledge is also important because some people may already have an idea as to what sort of coding they prefer to do. This teaching method could help the driven students to find more interesting things to work on and allow those who may not care as much to pass by while still learning essential coding knowledge.
#
#     The downside to this is it would create far more work upfront for those making the class lessons. Because everything can be more specialized, there necessarily must be more coding challenges to do. This also means more work grading in the end. Aside form this, I think it could be extremely helpful for all students because, again, it gives control back to the students.
